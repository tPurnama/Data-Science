# %% [markdown]
# Okay, it's time for us to start working with real data!  This project will require you to product **two** notebooks: one that processes data and dumps data to a pickle file, a second notebook that loads the pickle file and applies regression models to predict song popularity. Proposed due date: Friday October 26th, 5pm.
#
# 1. The following link is a fairly famous unprocessed data set which collected listening habits of approximately 1000 users:
# http://www.dtic.upf.edu/~ocelma/MusicRecommendationDataset/lastfm-1K.html
#
#     The data set is large (about 650 MB compressed), data is formatted one entry per line, tab-separated.  The first task is to process this data to recover some song statistics.  In particular, we would like to create (and save, using pickle), a pandas dataframe that contains:
#     * the number of times a song has been played
#     * percentage of the plays that came from users who self-identified as male
#     * average age of the listener
#     * percentage of plays that came from a user who played the song exactly once
#     * percentage of plays that came from a user who played the song at least five times
#
#     If there any missing values, decide how you will deal with them, and summarize your approach.
#
# 2. In this same pre-processing notebook, explore the data by generating some descriptive statistics.  After each code block, you should have summary statements, or code blocks should print out summary statements that are useful to a reader.
#
# 3. Complete this notebook by exporting the generated dataframe using pickle for posterity, but **don't commit your pickled file to the repository**.  Sometimes, it is more convenient to process the data locally rather than transmitting large processed data files.

# %% [markdown]
# 4. In a new notebook, load the dataframe object.  Using k-fold cross-validation, apply a linear regression model.  Here, the response variable is the number of times a song has been played based on what we know about the listeners.  Be sure to return the model score on both the training and validation data.
# 5. Explain your results.  Specifically address, if the assumption of linear response to the input features was reasonable.  You will want to study a plot of the model's residual.  Ideally, the residuals are small in magnitude, and are evenly distributed about the true values.  What are some possible improvements that can be made?
# 6. Suppose we are instead curious about whether a song will be played by a user based on a demographics.  Apply a logistic regression model and report your results.

# %% [markdown]
# # Notebook 1
#
# Before we begin the project, it would be better for us to import the package that we are going to use in the beginning to save time running the package when processing the code later on.
# There are several package that are going to be used in this notebook.
# 1. import pandas as pd : adding pandas package to the project in order to support doing the analysis. It enables to provide a fast, flexible and expressive data structures with a good designed for analysis.
# 2. import numpy as np : is used to enabled different operation for example working with array.
# 3. import tarfile : to enable working with tar file.
# 4. import io : is a system based package to read the file.
# 5. import pickle : to enable operating pickle for the dataset.
# 6. import matplotlib.pyplot as plt : for plotting the data visually. Like providing graph.

# %%
import pandas as pd
import numpy as np
import tarfile
import io
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# As we will used data in the form of .tar file here, we have to enable the tarfile package in this project. Then we can do our command code to open the file, otherwise the file will remain close. The following code will enable the file to be accessed in this notebook.

# %%
tar = tarfile.open("data/lastfm-dataset-1K.tar.gz")
print(tar)
# Out:
# <tarfile.TarFile object at 0x0000000009027400>

# %% [markdown]
# Now, the file is already enabled, we can check the details information of the file. As the tar file work like a zip file, we have to check what kind of files this tar file inside. We can check it by using the following code.

# %%
#tar = tarfile.open("sample.tar.gz", "r:gz")
for tarinfo in tar:
    print tarinfo.name, "is", tarinfo.size, "bytes in size and is",
    if tarinfo.isreg():
        print "a regular file."
    elif tarinfo.isdir():
        print "a directory."
    else:
        print "something else."
tar.close()
# Out:
# lastfm-dataset-1K is 0 bytes in size and is a directory.
# lastfm-dataset-1K/userid-profile.tsv is 37842 bytes in size and is a regular file.
# lastfm-dataset-1K/README.txt is 2235 bytes in size and is a regular file.
# lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv is 2529193595 bytes in size and is a regular file.

# %% [markdown]
# We can see on the above output that there are several files that we can access through this tarfile. Since our first task is to process this data to recover some song statistics, then we can take the file that contains the information about user and the song. In this case, we can access the `userid-profile.tsv` and `userid-timestamp-artid-artname-traid-traname.tsv`. The following code will access the file and add it into dataframe for further uses.

# %%
#Do note that using error_bad_lines=False will cause the offending lines to be skipped
dfuserid = pd.read_csv("lastfm-dataset-1K/userid-profile.tsv", sep="\t", error_bad_lines=False)

colnames = ["User ID", "Timestamp", "Artist ID", "Artist Name", "Track ID", "Track Name"]
dftrack = pd.read_csv("lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv", sep="\t", 
                 error_bad_lines=False, header=None, names=colnames)

# %% [markdown]
# We can check the number of obervations we have and print the first 5 rows of the dataframe by using the following code.

# %%
print(dfuserid.shape)
dfuserid.head()
print(dftrack.shape)
dftrack.head()
# Out:
# (992, 5)
# (19098862, 6)
#        User ID             Timestamp                             Artist ID  \
# 0  user_000001  2009-05-04T23:08:57Z  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1  user_000001  2009-05-04T13:54:10Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2  user_000001  2009-05-04T13:52:04Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3  user_000001  2009-05-04T13:42:52Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4  user_000001  2009-05-04T13:42:11Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
#
#   Artist Name Track ID                                  Track Name
# 0   Deep Dish      NaN  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1        坂本龍一      NaN           Composition 0919 (Live_2009_4_15)
# 2        坂本龍一      NaN                        Mc2 (Live_2009_4_15)
# 3        坂本龍一      NaN                     Hibari (Live_2009_4_15)
# 4        坂本龍一      NaN                        Mc1 (Live_2009_4_15)

# %% [markdown]
# Since the data are in two separate dataframe, we can combine it into one dataframe because we would like to get the information of the user who accessed the song as well. We can also check whether each variable contains any null values in it or not. The following code will join the two dataframe and check the existence of null values in each variable.

# %%
#join the two table into one
userjoin = dftrack.join(dfuserid.set_index('#id'), on=dftrack['User ID'])
print userjoin.shape #print the number of observations
userjoin.isna().any()
# Out:
# (19098862, 10)
# User ID        False
# Timestamp      False
# Artist ID       True
# Artist Name    False
# Track ID        True
# Track Name      True
# gender          True
# age             True
# country         True
# registered      True
# dtype: bool

# %% [markdown]
# As we can see on the above output, the variables that shown `true` in the output means that particular variable have missing values in their field, and no missing values otherwise.
# There are some missing data in the dataframe that we created based on user and song data. Before doing further operation, it would be best to deal with this missing data in the beginning. We can remove the null values from the dataset as it does not contains any information at all and we do not know to which categories it belong to. As such, we will deal with this null values in order to prevent it to impact our statistic. The following code will first check the missing data in the filed of `Track Name`, `age`, and `gender` as these variables will be our focus to develop our statistics.

# %% [markdown]
# ## Deal with the missing values

# %% [markdown]
# We can delete the null values by using the following code.

# %%
dfdropnull = userjoin.dropna(axis=0, subset=['Track Name', 'age', 'gender'])

# %% [markdown]
# The above code, wil delete the null values based on the three field that was defined. Now we can check again whether the three field that we want to focus on still have any null values.

# %%
dfdropnull.isna().any()
# Out:
# User ID        False
# Timestamp      False
# Artist ID       True
# Artist Name    False
# Track ID        True
# Track Name     False
# gender         False
# age            False
# country         True
# registered     False
# dtype: bool

# %% [markdown]
# Now, the variables track name, age and gender does not have any missing values, means that it is ready for further command. We can also print again the first 5 rows and the observations in this new dataset after we drop the null values by using the following code.

# %%
dfdropnull.head()
# Out:
#            User ID             Timestamp  \
# 74123  user_000003  2009-05-04T10:29:04Z
# 74124  user_000003  2009-04-21T16:56:35Z
# 74125  user_000003  2009-04-21T16:47:11Z
# 74126  user_000003  2009-04-21T16:32:54Z
# 74127  user_000003  2009-04-21T16:27:08Z
#
#                                   Artist ID    Artist Name  \
# 74123  ed442b01-8de1-4f0b-9188-e68b2960f050  Samuli Kemppi
# 74124  4730a989-8cf4-437b-9825-135f01644eab     Dirt Nasty
# 74125  4730a989-8cf4-437b-9825-135f01644eab     Dirt Nasty
# 74126  5879a47f-c54f-4ebe-8d63-cdc9c6310dd2  Mickey Avalon
# 74127  056e4f3e-d505-4dad-8ec1-d04f521cbb56      Daft Punk
#
#                                    Track ID                    Track Name  \
# 74123                                   NaN  Samuli Kemppi - January 2009
# 74124  f8ef2c6a-e71f-4f57-a8d5-876835192b0a          True Hollywood Story
# 74125  2c04113a-746b-491f-b999-892600730604         Gotta Leave This Town
# 74126                                   NaN                 F***In Em All
# 74127  10cdacde-e54a-412a-863b-81d9ea6b3df2                  Daftendirekt
#
#       gender   age        country    registered
# 74123      m  22.0  United States  Oct 30, 2005
# 74124      m  22.0  United States  Oct 30, 2005
# 74125      m  22.0  United States  Oct 30, 2005
# 74126      m  22.0  United States  Oct 30, 2005
# 74127      m  22.0  United States  Oct 30, 2005

# %%
dfdropnull.shape
# Out:
# (5296879, 10)

# %% [markdown]
# # New Trial

# %% [markdown]
# In particular, we would like to create (and save, using pickle), a pandas dataframe that contains:
#     * the number of times a song has been played
#     * percentage of the plays that came from users who self-identified as male
#     * average age of the listener
#     * percentage of plays that came from a user who played the song exactly once
#     * percentage of plays that came from a user who played the song at least five times
#
#     If there any missing values, decide how you will deal with them, and summarize your approach.
#
# 2. In this same pre-processing notebook, explore the data by generating some descriptive statistics.  After each code block, you should have summary statements, or code blocks should print out summary statements that are useful to a reader.
#
# 3. Complete this notebook by exporting the generated dataframe using pickle for posterity, but **don't commit your pickled file to the repository**.  Sometimes, it is more convenient to process the data locally rather than transmitting large processed data files.

# %% [markdown]
# ## Data Processing

# %% [markdown]
# Now the data is ready for further processing, we can take the dataframe that we already declared on the previous code to report the statistics of the song. Our focus is to create a dataframe that contains the following information:
#
#    * the number of times a song has been played
#    * percentage of the plays that came from users who self-identified as male
#    * average age of the listener
#    * percentage of plays that came from a user who played the song exactly once
#    * percentage of plays that came from a user who played the song at least five times
#
# As there are several operation need to be done to get the above mentioned statistics, we will separate the command in each of the requirement. First, we can get the total number of times a song has been played.

# %% [markdown]
# ### 1. The number of times a song has been played

# %%
We count the data based on the track name as we want to count how many times a song has been played.

# %%
#group and count the data based on track name, count the number of times a song has been played
numplayed = dfdropnull.groupby(['Track Name']).size().reset_index(name='Number of Played')
numplayed.sort_values(['Track Name'], ascending=[True])
# Out:
#                                                Track Name  Number of Played
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
# [454688 rows x 2 columns]

# %% [markdown]
# The above output shows the number of times a song has been played. For example, we can see that a song with the title ~Kuuhaku~ has been listened for 50 times by the user.

# %% [markdown]
# ### 2. Percentage of the plays that came from users who self-identified as male

# %% [markdown]
# In this part, we want to get the male percentage that plays the song, so we can filter the data based on gender and take only the number of male that access the song. The following code will group the data based on track name and gender.

# %%
#group the data based on track name and gender
byGender = dfdropnull.groupby(['Track Name', 'gender']).size().reset_index(name='By Gender')
#check the number of observations
byGender.shape
# Out:
# (553387, 3)

# %% [markdown]
# The following code will add the `byGender` dataframe into the previous number of song dataframe in order to get access into the total number of a song has been played to get the ratio of male percentages.

# %%
numbjoin = byGender.join(numplayed.set_index(['Track Name']), on=byGender['Track Name'])
numbjoin
# Out:
#                                                Track Name gender  By Gender  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...      f          1
# 1                                               ~Kuuhaku~      f         50
# 2                                                       !      m          2
# 3                                            ! (Foreword)      f         25
# 4                                            ! (Foreword)      m         13
# 5                                             ! (Forward)      m          6
# 6       ! (Performed By Ghostface Killah And Rhythm Ro...      m          8
# 7                          ! (The Song Formerly Known As)      m          1
# 8                                                     ! +      m          1
# 9                                      ! / Sn10.1.Ai 0711      m          1
# 10                                        ! / Sn2.Ai 0853      m          1
# 11                               ! Que Vida! (Stereo Mix)      m          2
# 12            !!! - Me And Guliani Down By The Schoolyard      f          2
# 13                            !!!Yeah!!!(Reggeaton Remix)      m          1
# 14                                                 !@*$%#      f         18
# 15                                     !Fire In The Hole!      m         11
# 16                                         !Get Up, Punk!      m          6
# 17                                             !Kamikaze!      m          9
# 18                                  !Pimps Up, Aces High!      m          6
# 19                            !Resistancia! (Bonus Track)      m          1
# 20                                    !Vaqueros Y Indios!      m          6
# 21                                                      #      m         12
# 22         # 173 - The Stills, Novillero, Fred Eaglesmith      m          1
# 23                  # 174 - The Organ, Sloan, Jill Barber      f          1
# 24                  # 174 - The Organ, Sloan, Jill Barber      m          1
# 25                                                  # 807      m          6
# 26                                           # Pending 24      f          1
# 27                                                   #...      m          2
# 28                                       #04 (Go On Home)      m          2
# 29      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...      m          1
# ...                                                   ...    ...        ...
# 553357                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）      f          2
# 553358                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）      f          1
# 553359  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...      f         27
# 553360                                          Ｗｈａｔ　Ｆｏｒ…      f          2
# 553361                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ      f          4
# 553362                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ      f         28
# 553363                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）      f         25
# 553364  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...      f          1
# 553365                                           Ｗｉｔｈ　Ｙｏｕ      f          1
# 553366                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ      f         12
# 553367                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）      f          4
# 553368               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）      f          7
# 553369                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ      f          9
# 553370                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ      f          9
# 553371                                         Ｙｏｕｒ　Ｗｏｒｌｄ      f          1
# 553372                                          Ｙｕｒａ　Ｙｕｒａ      f          4
# 553373                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ      f          1
# 553374                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）      f          1
# 553375                                     ～De Merveilles      m          4
# 553376                                          ～Sprout!～      f          1
# 553377                                    ～Toxic Gorilla～      f          1
# 553378                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～      f         17
# 553379                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）      f          2
# 553380                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）      f          1
# 553381                        ｢H×M×-Crash-Trap@｣ －A Type－      f          1
# 553382                        ｢H×M×-Crash-Trap@｣ －B Type－      f          1
# 553383                                          ､ﾏ､隕Vｪｺﾄﾁ      f         10
# 553384                                                ｺﾏ覈      f          1
# 553385                                     �   �H H�,   �      f          4
# 553386                                     �   �H H�,   �      m          1
#
#         Number of Played
# 0                      1
# 1                     50
# 2                      2
# 3                     38
# 4                     38
# 5                      6
# 6                      8
# 7                      1
# 8                      1
# 9                      1
# 10                     1
# 11                     2
# 12                     2
# 13                     1
# 14                    18
# 15                    11
# 16                     6
# 17                     9
# 18                     6
# 19                     1
# 20                     6
# 21                    12
# 22                     1
# 23                     2
# 24                     2
# 25                     6
# 26                     1
# 27                     2
# 28                     2
# 29                     1
# ...                  ...
# 553357                 2
# 553358                 1
# 553359                27
# 553360                 2
# 553361                 4
# 553362                28
# 553363                25
# 553364                 1
# 553365                 1
# 553366                12
# 553367                 4
# 553368                 7
# 553369                 9
# 553370                 9
# 553371                 1
# 553372                 4
# 553373                 1
# 553374                 1
# 553375                 4
# 553376                 1
# 553377                 1
# 553378                17
# 553379                 2
# 553380                 1
# 553381                 1
# 553382                 1
# 553383                10
# 553384                 1
# 553385                 5
# 553386                 5
#
# [553387 rows x 4 columns]

# %% [markdown]
# Next, we can select the male number from the dataset and put it into other dataframe.

# %%
maleuser = numbjoin[numbjoin['gender']=='m' ]
maleuser
# Out:
#                                                Track Name gender  By Gender  \
# 2                                                       !      m          2
# 4                                            ! (Foreword)      m         13
# 5                                             ! (Forward)      m          6
# 6       ! (Performed By Ghostface Killah And Rhythm Ro...      m          8
# 7                          ! (The Song Formerly Known As)      m          1
# 8                                                     ! +      m          1
# 9                                      ! / Sn10.1.Ai 0711      m          1
# 10                                        ! / Sn2.Ai 0853      m          1
# 11                               ! Que Vida! (Stereo Mix)      m          2
# 13                            !!!Yeah!!!(Reggeaton Remix)      m          1
# 15                                     !Fire In The Hole!      m         11
# 16                                         !Get Up, Punk!      m          6
# 17                                             !Kamikaze!      m          9
# 18                                  !Pimps Up, Aces High!      m          6
# 19                            !Resistancia! (Bonus Track)      m          1
# 20                                    !Vaqueros Y Indios!      m          6
# 21                                                      #      m         12
# 22         # 173 - The Stills, Novillero, Fred Eaglesmith      m          1
# 24                  # 174 - The Organ, Sloan, Jill Barber      m          1
# 25                                                  # 807      m          6
# 27                                                   #...      m          2
# 28                                       #04 (Go On Home)      m          2
# 29      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...      m          1
# 31                                                     #1      m         77
# 32                                    #1  (Album Version)      m          1
# 33                                     #1 (In Your Heart)      m          1
# 34                                             #1 Bad Boy      m         47
# 37                                               #1 Crush      m         43
# 38                                  #1 Crush (Goth Remix)      m          1
# 43                                             #1 Hit Jam      m          1
# ...                                                   ...    ...        ...
# 553077                                           눈 내리는 소리      m          1
# 553078                                             다 그런가요      m          2
# 553079                                              달의 뒤편      m          3
# 553083                                           마음을 기울이면      m          1
# 553085                                              별이 되어      m          2
# 553086                         보고 싶어서, 안고 싶어서, 만지고 싶어서...      m          1
# 553087                                                 블루      m          2
# 553088                                              비가내리면      m          2
# 553090                                               소녀시대      m          1
# 553091                                                스웨터      m          1
# 553092                                               어떻게…      m          2
# 553093                                            옛키스의 바람      m          2
# 553094                                                 오헤      m          2
# 553096                                  좋은 사람 (캐스커 Remix)      m          1
# 553097                                             준비된 이별      m          2
# 553098                                           지랄이 풍년이네      m          2
# 553099                                            크게 더 크게      m          2
# 553101                                             하모니카 쇨      m          1
# 553102                                       한쪽 뺨으로 웃는 여자      m          1
# 553104                                                후애야      m          2
# 553107                                     ﺍﻠﻮﺮﺪﺓ ﺍﻠﺑﻴﻀﺎﺀ      m          1
# 553114                                       ４月１日、花畑にて...      m          1
# 553174                                             Ｄｉｄ　Ｙａ      m          1
# 553186                                          Ｅｎｅｒｇｅｔｉｃ      m          1
# 553209                                     Ｈｏｕｓｅ　Ｏｆ　Ｃａｒｄｓ      m          5
# 553211                                  Ｉ　Ｄｉｄ　Ｉｔ　Ｆｏｒ　Ｌｏｖｅ      m          1
# 553247                                         Ｍａｉｎ　Ｔｈｅｍｅ      m          2
# 553306                                             Ｒｙｄｅｅｎ      m          1
# 553375                                     ～De Merveilles      m          4
# 553386                                     �   �H H�,   �      m          1
#
#         Number of Played
# 2                      2
# 4                     38
# 5                      6
# 6                      8
# 7                      1
# 8                      1
# 9                      1
# 10                     1
# 11                     2
# 13                     1
# 15                    11
# 16                     6
# 17                     9
# 18                     6
# 19                     1
# 20                     6
# 21                    12
# 22                     1
# 24                     2
# 25                     6
# 27                     2
# 28                     2
# 29                     1
# 31                   117
# 32                     1
# 33                     1
# 34                    47
# 37                    70
# 38                     1
# 43                     3
# ...                  ...
# 553077                 1
# 553078                 2
# 553079                 3
# 553083                 1
# 553085                 2
# 553086                 1
# 553087                 2
# 553088                 2
# 553090                 1
# 553091                 1
# 553092                 2
# 553093                 2
# 553094                 2
# 553096                 1
# 553097                 2
# 553098                 2
# 553099                 2
# 553101                 1
# 553102                 1
# 553104                 2
# 553107                 1
# 553114                 1
# 553174                 1
# 553186                 1
# 553209                 5
# 553211                 1
# 553247                 2
# 553306                 1
# 553375                 4
# 553386                 5
#
# [346457 rows x 4 columns]

# %% [markdown]
# Now we have the total number of times a song has been played and the total numbe of times the song was played by male user. We can compute the percentage of male listener to the total number of song has been played.

# %%
maleuser['Male Percentage'] = (maleuser['By Gender'] / maleuser['Number of Played']) * 100
maleuser = maleuser.infer_objects() #convert datatypes
print maleuser.dtypes

maleuser['Male Percentage'] = maleuser['Male Percentage'].round(2)
maleuser
# Out:
# Track Name           object
# gender               object
# By Gender             int64
# Number of Played      int64
# Male Percentage     float64
# dtype: object
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                Track Name gender  By Gender  \
# 2                                                       !      m          2
# 4                                            ! (Foreword)      m         13
# 5                                             ! (Forward)      m          6
# 6       ! (Performed By Ghostface Killah And Rhythm Ro...      m          8
# 7                          ! (The Song Formerly Known As)      m          1
# 8                                                     ! +      m          1
# 9                                      ! / Sn10.1.Ai 0711      m          1
# 10                                        ! / Sn2.Ai 0853      m          1
# 11                               ! Que Vida! (Stereo Mix)      m          2
# 13                            !!!Yeah!!!(Reggeaton Remix)      m          1
# 15                                     !Fire In The Hole!      m         11
# 16                                         !Get Up, Punk!      m          6
# 17                                             !Kamikaze!      m          9
# 18                                  !Pimps Up, Aces High!      m          6
# 19                            !Resistancia! (Bonus Track)      m          1
# 20                                    !Vaqueros Y Indios!      m          6
# 21                                                      #      m         12
# 22         # 173 - The Stills, Novillero, Fred Eaglesmith      m          1
# 24                  # 174 - The Organ, Sloan, Jill Barber      m          1
# 25                                                  # 807      m          6
# 27                                                   #...      m          2
# 28                                       #04 (Go On Home)      m          2
# 29      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...      m          1
# 31                                                     #1      m         77
# 32                                    #1  (Album Version)      m          1
# 33                                     #1 (In Your Heart)      m          1
# 34                                             #1 Bad Boy      m         47
# 37                                               #1 Crush      m         43
# 38                                  #1 Crush (Goth Remix)      m          1
# 43                                             #1 Hit Jam      m          1
# ...                                                   ...    ...        ...
# 553077                                           눈 내리는 소리      m          1
# 553078                                             다 그런가요      m          2
# 553079                                              달의 뒤편      m          3
# 553083                                           마음을 기울이면      m          1
# 553085                                              별이 되어      m          2
# 553086                         보고 싶어서, 안고 싶어서, 만지고 싶어서...      m          1
# 553087                                                 블루      m          2
# 553088                                              비가내리면      m          2
# 553090                                               소녀시대      m          1
# 553091                                                스웨터      m          1
# 553092                                               어떻게…      m          2
# 553093                                            옛키스의 바람      m          2
# 553094                                                 오헤      m          2
# 553096                                  좋은 사람 (캐스커 Remix)      m          1
# 553097                                             준비된 이별      m          2
# 553098                                           지랄이 풍년이네      m          2
# 553099                                            크게 더 크게      m          2
# 553101                                             하모니카 쇨      m          1
# 553102                                       한쪽 뺨으로 웃는 여자      m          1
# 553104                                                후애야      m          2
# 553107                                     ﺍﻠﻮﺮﺪﺓ ﺍﻠﺑﻴﻀﺎﺀ      m          1
# 553114                                       ４月１日、花畑にて...      m          1
# 553174                                             Ｄｉｄ　Ｙａ      m          1
# 553186                                          Ｅｎｅｒｇｅｔｉｃ      m          1
# 553209                                     Ｈｏｕｓｅ　Ｏｆ　Ｃａｒｄｓ      m          5
# 553211                                  Ｉ　Ｄｉｄ　Ｉｔ　Ｆｏｒ　Ｌｏｖｅ      m          1
# 553247                                         Ｍａｉｎ　Ｔｈｅｍｅ      m          2
# 553306                                             Ｒｙｄｅｅｎ      m          1
# 553375                                     ～De Merveilles      m          4
# 553386                                     �   �H H�,   �      m          1
#
#         Number of Played  Male Percentage
# 2                      2           100.00
# 4                     38            34.21
# 5                      6           100.00
# 6                      8           100.00
# 7                      1           100.00
# 8                      1           100.00
# 9                      1           100.00
# 10                     1           100.00
# 11                     2           100.00
# 13                     1           100.00
# 15                    11           100.00
# 16                     6           100.00
# 17                     9           100.00
# 18                     6           100.00
# 19                     1           100.00
# 20                     6           100.00
# 21                    12           100.00
# 22                     1           100.00
# 24                     2            50.00
# 25                     6           100.00
# 27                     2           100.00
# 28                     2           100.00
# 29                     1           100.00
# 31                   117            65.81
# 32                     1           100.00
# 33                     1           100.00
# 34                    47           100.00
# 37                    70            61.43
# 38                     1           100.00
# 43                     3            33.33
# ...                  ...              ...
# 553077                 1           100.00
# 553078                 2           100.00
# 553079                 3           100.00
# 553083                 1           100.00
# 553085                 2           100.00
# 553086                 1           100.00
# 553087                 2           100.00
# 553088                 2           100.00
# 553090                 1           100.00
# 553091                 1           100.00
# 553092                 2           100.00
# 553093                 2           100.00
# 553094                 2           100.00
# 553096                 1           100.00
# 553097                 2           100.00
# 553098                 2           100.00
# 553099                 2           100.00
# 553101                 1           100.00
# 553102                 1           100.00
# 553104                 2           100.00
# 553107                 1           100.00
# 553114                 1           100.00
# 553174                 1           100.00
# 553186                 1           100.00
# 553209                 5           100.00
# 553211                 1           100.00
# 553247                 2           100.00
# 553306                 1           100.00
# 553375                 4           100.00
# 553386                 5            20.00
#
# [346457 rows x 5 columns]

# %% [markdown]
# Since, we got the male percentage, we can then merger it into our final dataset which contains the number of times a song has been played, the numbe of listener who is identified as male and its percentage.

# %%
#merging the result together
summarydf = numplayed[['Track Name', 'Number of Played']].merge(maleuser[['Track Name', 'By Gender', 'Male Percentage']], on='Track Name', how='left')
summarydf
# Out:
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage
# 0             NaN              NaN
# 1             NaN              NaN
# 2             2.0           100.00
# 3            13.0            34.21
# 4             6.0           100.00
# 5             8.0           100.00
# 6             1.0           100.00
# 7             1.0           100.00
# 8             1.0           100.00
# 9             1.0           100.00
# 10            2.0           100.00
# 11            NaN              NaN
# 12            1.0           100.00
# 13            NaN              NaN
# 14           11.0           100.00
# 15            6.0           100.00
# 16            9.0           100.00
# 17            6.0           100.00
# 18            1.0           100.00
# 19            6.0           100.00
# 20           12.0           100.00
# 21            1.0           100.00
# 22            1.0            50.00
# 23            6.0           100.00
# 24            NaN              NaN
# 25            2.0           100.00
# 26            2.0           100.00
# 27            1.0           100.00
# 28           77.0            65.81
# 29            1.0           100.00
# ...           ...              ...
# 454658        NaN              NaN
# 454659        NaN              NaN
# 454660        NaN              NaN
# 454661        NaN              NaN
# 454662        NaN              NaN
# 454663        NaN              NaN
# 454664        NaN              NaN
# 454665        NaN              NaN
# 454666        NaN              NaN
# 454667        NaN              NaN
# 454668        NaN              NaN
# 454669        NaN              NaN
# 454670        NaN              NaN
# 454671        NaN              NaN
# 454672        NaN              NaN
# 454673        NaN              NaN
# 454674        NaN              NaN
# 454675        NaN              NaN
# 454676        NaN              NaN
# 454677        4.0           100.00
# 454678        NaN              NaN
# 454679        NaN              NaN
# 454680        NaN              NaN
# 454681        NaN              NaN
# 454682        NaN              NaN
# 454683        NaN              NaN
# 454684        NaN              NaN
# 454685        NaN              NaN
# 454686        NaN              NaN
# 454687        1.0            20.00
#
# [454688 rows x 4 columns]

# %% [markdown]
# We can see the male percentage for each song, and the value that is missing like `NaN` means that it was listened by female user. As we did not count the female ratio so we left it as null.

# %% [markdown]
# ## Average age of the listener

# %% [markdown]
# In this part, we are going to compute the average age of the user based on each song with the following code.

# %%
meanage = dfdropnull.groupby(['Track Name'])['age'].mean().reset_index(name='AVG Age')
meanage.sort_values(['Track Name'], ascending=[True])
# Out:
#                                                Track Name    AVG Age
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...  20.000000
# 1                                               ~Kuuhaku~  20.000000
# 2                                                       !  30.000000
# 3                                            ! (Foreword)  24.526316
# 4                                             ! (Forward)  25.000000
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...  23.250000
# 6                          ! (The Song Formerly Known As)  28.000000
# 7                                                     ! +  28.000000
# 8                                      ! / Sn10.1.Ai 0711  29.000000
# 9                                         ! / Sn2.Ai 0853  29.000000
# 10                               ! Que Vida! (Stereo Mix)  20.000000
# 11            !!! - Me And Guliani Down By The Schoolyard  22.000000
# 12                            !!!Yeah!!!(Reggeaton Remix)  18.000000
# 13                                                 !@*$%#  24.111111
# 14                                     !Fire In The Hole!  23.181818
# 15                                         !Get Up, Punk!  23.500000
# 16                                             !Kamikaze!  23.222222
# 17                                  !Pimps Up, Aces High!  23.333333
# 18                            !Resistancia! (Bonus Track)  26.000000
# 19                                    !Vaqueros Y Indios!  23.500000
# 20                                                      #  25.000000
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith  27.000000
# 22                  # 174 - The Organ, Sloan, Jill Barber  27.500000
# 23                                                  # 807  34.333333
# 24                                           # Pending 24  22.000000
# 25                                                   #...  20.000000
# 26                                       #04 (Go On Home)  33.000000
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...  36.000000
# 28                                                     #1  24.504274
# 29                                    #1  (Album Version)  42.000000
# ...                                                   ...        ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...  21.000000
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）  21.000000
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）  21.000000
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...  21.000000
# 454662                                          Ｗｈａｔ　Ｆｏｒ…  21.000000
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ  21.000000
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ  21.000000
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）  21.000000
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...  21.000000
# 454667                                           Ｗｉｔｈ　Ｙｏｕ  21.000000
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ  21.000000
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）  21.000000
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）  21.000000
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ  21.000000
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ  21.000000
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ  21.000000
# 454674                                          Ｙｕｒａ　Ｙｕｒａ  21.000000
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ  21.000000
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）  21.000000
# 454677                                     ～De Merveilles  23.000000
# 454678                                          ～Sprout!～  21.000000
# 454679                                    ～Toxic Gorilla～  21.000000
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～  21.000000
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）  21.000000
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）  21.000000
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－  20.000000
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－  20.000000
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ  21.000000
# 454686                                                ｺﾏ覈  21.000000
# 454687                                     �   �H H�,   �  25.400000
#
# [454688 rows x 2 columns]

# %% [markdown]
# Then, we can combined the result with our final data set.

# %%
summarydf = summarydf[['Track Name', 'Number of Played', 'By Gender', 'Male Percentage']].merge(meanage[['Track Name', 'AVG Age']], on='Track Name', how='left')
summarydf
# Out:
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage    AVG Age
# 0             NaN              NaN  20.000000
# 1             NaN              NaN  20.000000
# 2             2.0           100.00  30.000000
# 3            13.0            34.21  24.526316
# 4             6.0           100.00  25.000000
# 5             8.0           100.00  23.250000
# 6             1.0           100.00  28.000000
# 7             1.0           100.00  28.000000
# 8             1.0           100.00  29.000000
# 9             1.0           100.00  29.000000
# 10            2.0           100.00  20.000000
# 11            NaN              NaN  22.000000
# 12            1.0           100.00  18.000000
# 13            NaN              NaN  24.111111
# 14           11.0           100.00  23.181818
# 15            6.0           100.00  23.500000
# 16            9.0           100.00  23.222222
# 17            6.0           100.00  23.333333
# 18            1.0           100.00  26.000000
# 19            6.0           100.00  23.500000
# 20           12.0           100.00  25.000000
# 21            1.0           100.00  27.000000
# 22            1.0            50.00  27.500000
# 23            6.0           100.00  34.333333
# 24            NaN              NaN  22.000000
# 25            2.0           100.00  20.000000
# 26            2.0           100.00  33.000000
# 27            1.0           100.00  36.000000
# 28           77.0            65.81  24.504274
# 29            1.0           100.00  42.000000
# ...           ...              ...        ...
# 454658        NaN              NaN  21.000000
# 454659        NaN              NaN  21.000000
# 454660        NaN              NaN  21.000000
# 454661        NaN              NaN  21.000000
# 454662        NaN              NaN  21.000000
# 454663        NaN              NaN  21.000000
# 454664        NaN              NaN  21.000000
# 454665        NaN              NaN  21.000000
# 454666        NaN              NaN  21.000000
# 454667        NaN              NaN  21.000000
# 454668        NaN              NaN  21.000000
# 454669        NaN              NaN  21.000000
# 454670        NaN              NaN  21.000000
# 454671        NaN              NaN  21.000000
# 454672        NaN              NaN  21.000000
# 454673        NaN              NaN  21.000000
# 454674        NaN              NaN  21.000000
# 454675        NaN              NaN  21.000000
# 454676        NaN              NaN  21.000000
# 454677        4.0           100.00  23.000000
# 454678        NaN              NaN  21.000000
# 454679        NaN              NaN  21.000000
# 454680        NaN              NaN  21.000000
# 454681        NaN              NaN  21.000000
# 454682        NaN              NaN  21.000000
# 454683        NaN              NaN  20.000000
# 454684        NaN              NaN  20.000000
# 454685        NaN              NaN  21.000000
# 454686        NaN              NaN  21.000000
# 454687        1.0            20.00  25.400000
#
# [454688 rows x 5 columns]

# %%
Now, our final dataset has an additional column of average age of its user.

# %% [markdown]
# ## Percentage of plays that came from a user who played the song exactly once

# %% [markdown]
# In this section, we are going to compute the percentage of song came from the user who played the song exactly once. First we can group our data based on the track name and user id and count the number of played based on each user for each song.

# %%
userplayed = dfdropnull.groupby(['Track Name', 'User ID']).size().reset_index(name='By User')
userplayed
# Out:
#                                                 Track Name      User ID  \
# 0        \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...  user_000125
# 1                                                ~Kuuhaku~  user_000033
# 2                                                        !  user_000134
# 3                                             ! (Foreword)  user_000026
# 4                                             ! (Foreword)  user_000083
# 5                                             ! (Foreword)  user_000182
# 6                                             ! (Foreword)  user_000206
# 7                                             ! (Foreword)  user_000344
# 8                                             ! (Foreword)  user_000356
# 9                                              ! (Forward)  user_000306
# 10       ! (Performed By Ghostface Killah And Rhythm Ro...  user_000199
# 11       ! (Performed By Ghostface Killah And Rhythm Ro...  user_000351
# 12                          ! (The Song Formerly Known As)  user_000167
# 13                                                     ! +  user_000167
# 14                                      ! / Sn10.1.Ai 0711  user_000053
# 15                                         ! / Sn2.Ai 0853  user_000053
# 16                                ! Que Vida! (Stereo Mix)  user_000159
# 17             !!! - Me And Guliani Down By The Schoolyard  user_000238
# 18                             !!!Yeah!!!(Reggeaton Remix)  user_000084
# 19                                                  !@*$%#  user_000060
# 20                                                  !@*$%#  user_000086
# 21                                                  !@*$%#  user_000091
# 22                                                  !@*$%#  user_000251
# 23                                      !Fire In The Hole!  user_000046
# 24                                      !Fire In The Hole!  user_000349
# 25                                          !Get Up, Punk!  user_000046
# 26                                          !Get Up, Punk!  user_000349
# 27                                              !Kamikaze!  user_000046
# 28                                              !Kamikaze!  user_000349
# 29                                   !Pimps Up, Aces High!  user_000046
# ...                                                    ...          ...
# 1154172  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...  user_000141
# 1154173                                          Ｗｈａｔ　Ｆｏｒ…  user_000141
# 1154174                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ  user_000141
# 1154175                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ  user_000141
# 1154176                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）  user_000141
# 1154177  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...  user_000141
# 1154178                                           Ｗｉｔｈ　Ｙｏｕ  user_000141
# 1154179                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ  user_000141
# 1154180                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）  user_000141
# 1154181               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）  user_000141
# 1154182                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ  user_000141
# 1154183                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ  user_000141
# 1154184                                         Ｙｏｕｒ　Ｗｏｒｌｄ  user_000141
# 1154185                                          Ｙｕｒａ　Ｙｕｒａ  user_000141
# 1154186                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ  user_000141
# 1154187                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）  user_000141
# 1154188                                     ～De Merveilles  user_000188
# 1154189                                          ～Sprout!～  user_000141
# 1154190                                    ～Toxic Gorilla～  user_000141
# 1154191                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～  user_000141
# 1154192                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）  user_000141
# 1154193                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）  user_000141
# 1154194                        ｢H×M×-Crash-Trap@｣ －A Type－  user_000033
# 1154195                        ｢H×M×-Crash-Trap@｣ －B Type－  user_000033
# 1154196                                          ､ﾏ､隕Vｪｺﾄﾁ  user_000141
# 1154197                                                ｺﾏ覈  user_000141
# 1154198                                     �   �H H�,   �  user_000012
# 1154199                                     �   �H H�,   �  user_000086
# 1154200                                     �   �H H�,   �  user_000131
# 1154201                                     �   �H H�,   �  user_000134
#
#          By User
# 0              1
# 1             50
# 2              2
# 3              8
# 4              2
# 5              6
# 6             17
# 7              4
# 8              1
# 9              6
# 10             3
# 11             5
# 12             1
# 13             1
# 14             1
# 15             1
# 16             2
# 17             2
# 18             1
# 19             2
# 20             1
# 21             1
# 22            14
# 23             2
# 24             9
# 25             3
# 26             3
# 27             2
# 28             7
# 29             2
# ...          ...
# 1154172       27
# 1154173        2
# 1154174        4
# 1154175       28
# 1154176       25
# 1154177        1
# 1154178        1
# 1154179       12
# 1154180        4
# 1154181        7
# 1154182        9
# 1154183        9
# 1154184        1
# 1154185        4
# 1154186        1
# 1154187        1
# 1154188        4
# 1154189        1
# 1154190        1
# 1154191       17
# 1154192        2
# 1154193        1
# 1154194        1
# 1154195        1
# 1154196       10
# 1154197        1
# 1154198        1
# 1154199        1
# 1154200        2
# 1154201        1
#
# [1154202 rows x 3 columns]

# %%
Then, we can select the user who played the song exactly once by using the following code.

# %%
played1 = userplayed[userplayed['By User']==1 ]
played1
# Out:
#                                                 Track Name      User ID  \
# 0        \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...  user_000125
# 8                                             ! (Foreword)  user_000356
# 12                          ! (The Song Formerly Known As)  user_000167
# 13                                                     ! +  user_000167
# 14                                      ! / Sn10.1.Ai 0711  user_000053
# 15                                         ! / Sn2.Ai 0853  user_000053
# 18                             !!!Yeah!!!(Reggeaton Remix)  user_000084
# 20                                                  !@*$%#  user_000086
# 21                                                  !@*$%#  user_000091
# 31                             !Resistancia! (Bonus Track)  user_000149
# 35          # 173 - The Stills, Novillero, Fred Eaglesmith  user_000021
# 36                   # 174 - The Organ, Sloan, Jill Barber  user_000012
# 37                   # 174 - The Organ, Sloan, Jill Barber  user_000021
# 40                                            # Pending 24  user_000204
# 43       #068 - Tad Marks, Stephen Nachmanovitch, Boldw...  user_000067
# 46                                                      #1  user_000021
# 47                                                      #1  user_000034
# 48                                                      #1  user_000065
# 51                                                      #1  user_000127
# 53                                                      #1  user_000189
# 55                                                      #1  user_000223
# 56                                                      #1  user_000242
# 59                                                      #1  user_000273
# 61                                                      #1  user_000304
# 64                                                      #1  user_000351
# 65                                     #1  (Album Version)  user_000210
# 66                                      #1 (In Your Heart)  user_000320
# 68                                     #1 Chance Pirate Tv  user_000043
# 76                                                #1 Crush  user_000198
# 78                                                #1 Crush  user_000260
# ...                                                    ...          ...
# 1154032                      Ｉｎｖｏｋｅ（フェイズ・シフト・アーマード・ヴァージョン）  user_000141
# 1154033                                     Ｉｎｖｏｋｅ－インヴォーク－  user_000141
# 1154052                                   Ｌｉｖｉｎｇ　Ｄａｙｌｉｇｈｔｓ  user_000141
# 1154057                                        Ｌｏｖｅ　Ｌｅｔｔｅｒ  user_000141
# 1154086                     Ｎｏｗ　Ａｎｄ　Ｆｏｒｅｖｅｒ　(Ｉｎｓｔｒｕｍｅｎｔａｌ)  user_000141
# 1154092                                        Ｐｅｒｆｅｃｔ　Ｄａｙ  user_000141
# 1154095                                         Ｐｉｅｄ　Ｐｉｐｅｒ  user_000141
# 1154106                                     Ｒｈｙｔｈｍ　Ｅｍｏｔｉｏｎ  user_000141
# 1154114                                             Ｒｏｓｉｅｒ  user_000141
# 1154119                                             Ｒｙｄｅｅｎ  user_000035
# 1154138                                  Ｓｔｉｌｌ　Ｉｎ　Ｍｙ　Ｈｅａｒｔ  user_000141
# 1154155                                              Ｔｏｘｉｃ  user_000141
# 1154156                         Ｔｗｉｎｋｌｅ　Ｍｉｌｌｉｏｎ　Ｒｅｎｄｅｚｖｏｕｓ  user_000141
# 1154166                                  Ｖｅｒｔｉｃａｌ　Ｉｎｆｉｎｉｔｙ  user_000141
# 1154167                                  Ｗａｒｐｅｄ　Ｒｅｆｌｅｃｔｉｏｎ  user_000141
# 1154171                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）  user_000141
# 1154177  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...  user_000141
# 1154178                                           Ｗｉｔｈ　Ｙｏｕ  user_000141
# 1154184                                         Ｙｏｕｒ　Ｗｏｒｌｄ  user_000141
# 1154186                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ  user_000141
# 1154187                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）  user_000141
# 1154189                                          ～Sprout!～  user_000141
# 1154190                                    ～Toxic Gorilla～  user_000141
# 1154193                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）  user_000141
# 1154194                        ｢H×M×-Crash-Trap@｣ －A Type－  user_000033
# 1154195                        ｢H×M×-Crash-Trap@｣ －B Type－  user_000033
# 1154197                                                ｺﾏ覈  user_000141
# 1154198                                     �   �H H�,   �  user_000012
# 1154199                                     �   �H H�,   �  user_000086
# 1154201                                     �   �H H�,   �  user_000134
#
#          By User
# 0              1
# 8              1
# 12             1
# 13             1
# 14             1
# 15             1
# 18             1
# 20             1
# 21             1
# 31             1
# 35             1
# 36             1
# 37             1
# 40             1
# 43             1
# 46             1
# 47             1
# 48             1
# 51             1
# 53             1
# 55             1
# 56             1
# 59             1
# 61             1
# 64             1
# 65             1
# 66             1
# 68             1
# 76             1
# 78             1
# ...          ...
# 1154032        1
# 1154033        1
# 1154052        1
# 1154057        1
# 1154086        1
# 1154092        1
# 1154095        1
# 1154106        1
# 1154114        1
# 1154119        1
# 1154138        1
# 1154155        1
# 1154156        1
# 1154166        1
# 1154167        1
# 1154171        1
# 1154177        1
# 1154178        1
# 1154184        1
# 1154186        1
# 1154187        1
# 1154189        1
# 1154190        1
# 1154193        1
# 1154194        1
# 1154195        1
# 1154197        1
# 1154198        1
# 1154199        1
# 1154201        1
#
# [516762 rows x 3 columns]

# %% [markdown]
# Next, we can compute how many user has played the song exactly once for each song.

# %%
sumplayed1 = played1.groupby(['Track Name']).size().reset_index(name='Played Once')
sumplayed1
# Out:
#                                                Track Name  Played Once
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...            1
# 1                                            ! (Foreword)            1
# 2                          ! (The Song Formerly Known As)            1
# 3                                                     ! +            1
# 4                                      ! / Sn10.1.Ai 0711            1
# 5                                         ! / Sn2.Ai 0853            1
# 6                             !!!Yeah!!!(Reggeaton Remix)            1
# 7                                                  !@*$%#            2
# 8                             !Resistancia! (Bonus Track)            1
# 9          # 173 - The Stills, Novillero, Fred Eaglesmith            1
# 10                  # 174 - The Organ, Sloan, Jill Barber            2
# 11                                           # Pending 24            1
# 12      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...            1
# 13                                                     #1           10
# 14                                    #1  (Album Version)            1
# 15                                     #1 (In Your Heart)            1
# 16                                    #1 Chance Pirate Tv            1
# 17                                               #1 Crush            6
# 18                                  #1 Crush (Goth Remix)            1
# 19                                            #1 Da Woman            1
# 20                                             #1 Hit Jam            1
# 21                                            #1 Hit Song            2
# 22                                       #1 Is Number Two            1
# 23                                           #1 Must Have            3
# 24                                                #1 Song            1
# 25                                              #1 Target            1
# 26                                                #1 Zero            3
# 27                                                    #10            1
# 28                                #101 - Wizard’S Council            1
# 29                                #102 - Saskatoon Secret            1
# ...                                                   ...          ...
# 280413                              Ｉ　Ｗａｎｎａ　Ｇｏ　Ｔｏ　Ａ　Ｐｌａｃｅ            1
# 280414                                 Ｉｎｖｏｋｅ（インストゥルメンタル）            1
# 280415                      Ｉｎｖｏｋｅ（フェイズ・シフト・アーマード・ヴァージョン）            1
# 280416                                     Ｉｎｖｏｋｅ－インヴォーク－            1
# 280417                                   Ｌｉｖｉｎｇ　Ｄａｙｌｉｇｈｔｓ            1
# 280418                                        Ｌｏｖｅ　Ｌｅｔｔｅｒ            1
# 280419                     Ｎｏｗ　Ａｎｄ　Ｆｏｒｅｖｅｒ　(Ｉｎｓｔｒｕｍｅｎｔａｌ)            1
# 280420                                        Ｐｅｒｆｅｃｔ　Ｄａｙ            1
# 280421                                         Ｐｉｅｄ　Ｐｉｐｅｒ            1
# 280422                                     Ｒｈｙｔｈｍ　Ｅｍｏｔｉｏｎ            1
# 280423                                             Ｒｏｓｉｅｒ            1
# 280424                                             Ｒｙｄｅｅｎ            1
# 280425                                  Ｓｔｉｌｌ　Ｉｎ　Ｍｙ　Ｈｅａｒｔ            1
# 280426                                              Ｔｏｘｉｃ            1
# 280427                         Ｔｗｉｎｋｌｅ　Ｍｉｌｌｉｏｎ　Ｒｅｎｄｅｚｖｏｕｓ            1
# 280428                                  Ｖｅｒｔｉｃａｌ　Ｉｎｆｉｎｉｔｙ            1
# 280429                                  Ｗａｒｐｅｄ　Ｒｅｆｌｅｃｔｉｏｎ            1
# 280430                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）            1
# 280431  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...            1
# 280432                                           Ｗｉｔｈ　Ｙｏｕ            1
# 280433                                         Ｙｏｕｒ　Ｗｏｒｌｄ            1
# 280434                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ            1
# 280435                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）            1
# 280436                                          ～Sprout!～            1
# 280437                                    ～Toxic Gorilla～            1
# 280438                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）            1
# 280439                        ｢H×M×-Crash-Trap@｣ －A Type－            1
# 280440                        ｢H×M×-Crash-Trap@｣ －B Type－            1
# 280441                                                ｺﾏ覈            1
# 280442                                     �   �H H�,   �            3
#
# [280443 rows x 2 columns]

# %% [markdown]
# And then, merge the value into our final data set.

# %%
summarydf = summarydf.join(sumplayed1.set_index(['Track Name']), on=summarydf['Track Name'])
summarydf
# Out:
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage    AVG Age  Played Once
# 0             NaN              NaN  20.000000          1.0
# 1             NaN              NaN  20.000000          NaN
# 2             2.0           100.00  30.000000          NaN
# 3            13.0            34.21  24.526316          1.0
# 4             6.0           100.00  25.000000          NaN
# 5             8.0           100.00  23.250000          NaN
# 6             1.0           100.00  28.000000          1.0
# 7             1.0           100.00  28.000000          1.0
# 8             1.0           100.00  29.000000          1.0
# 9             1.0           100.00  29.000000          1.0
# 10            2.0           100.00  20.000000          NaN
# 11            NaN              NaN  22.000000          NaN
# 12            1.0           100.00  18.000000          1.0
# 13            NaN              NaN  24.111111          2.0
# 14           11.0           100.00  23.181818          NaN
# 15            6.0           100.00  23.500000          NaN
# 16            9.0           100.00  23.222222          NaN
# 17            6.0           100.00  23.333333          NaN
# 18            1.0           100.00  26.000000          1.0
# 19            6.0           100.00  23.500000          NaN
# 20           12.0           100.00  25.000000          NaN
# 21            1.0           100.00  27.000000          1.0
# 22            1.0            50.00  27.500000          2.0
# 23            6.0           100.00  34.333333          NaN
# 24            NaN              NaN  22.000000          1.0
# 25            2.0           100.00  20.000000          NaN
# 26            2.0           100.00  33.000000          NaN
# 27            1.0           100.00  36.000000          1.0
# 28           77.0            65.81  24.504274         10.0
# 29            1.0           100.00  42.000000          1.0
# ...           ...              ...        ...          ...
# 454658        NaN              NaN  21.000000          NaN
# 454659        NaN              NaN  21.000000          NaN
# 454660        NaN              NaN  21.000000          1.0
# 454661        NaN              NaN  21.000000          NaN
# 454662        NaN              NaN  21.000000          NaN
# 454663        NaN              NaN  21.000000          NaN
# 454664        NaN              NaN  21.000000          NaN
# 454665        NaN              NaN  21.000000          NaN
# 454666        NaN              NaN  21.000000          1.0
# 454667        NaN              NaN  21.000000          1.0
# 454668        NaN              NaN  21.000000          NaN
# 454669        NaN              NaN  21.000000          NaN
# 454670        NaN              NaN  21.000000          NaN
# 454671        NaN              NaN  21.000000          NaN
# 454672        NaN              NaN  21.000000          NaN
# 454673        NaN              NaN  21.000000          1.0
# 454674        NaN              NaN  21.000000          NaN
# 454675        NaN              NaN  21.000000          1.0
# 454676        NaN              NaN  21.000000          1.0
# 454677        4.0           100.00  23.000000          NaN
# 454678        NaN              NaN  21.000000          1.0
# 454679        NaN              NaN  21.000000          1.0
# 454680        NaN              NaN  21.000000          NaN
# 454681        NaN              NaN  21.000000          NaN
# 454682        NaN              NaN  21.000000          1.0
# 454683        NaN              NaN  20.000000          1.0
# 454684        NaN              NaN  20.000000          1.0
# 454685        NaN              NaN  21.000000          NaN
# 454686        NaN              NaN  21.000000          1.0
# 454687        1.0            20.00  25.400000          3.0
#
# [454688 rows x 6 columns]

# %% [markdown]
# Finally, as it is in the sam dataset, we can directly compute the percentage.

# %%
summarydf['Once Percentage'] = (summarydf['Played Once'] / summarydf['Number of Played']) * 100
summarydf = summarydf.infer_objects() #convert datatypes
print summarydf.dtypes

summarydf['Once Percentage'] = summarydf['Once Percentage'].round(2)
summarydf
# Out:
# Track Name           object
# Number of Played      int64
# By Gender           float64
# Male Percentage     float64
# AVG Age             float64
# Played Once         float64
# Once Percentage     float64
# dtype: object
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\series.py:1826: RuntimeWarning: invalid value encountered in rint
#   result = com._values_from_object(self).round(decimals)
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage    AVG Age  Played Once  Once Percentage
# 0             NaN              NaN  20.000000          1.0           100.00
# 1             NaN              NaN  20.000000          NaN              NaN
# 2             2.0           100.00  30.000000          NaN              NaN
# 3            13.0            34.21  24.526316          1.0             2.63
# 4             6.0           100.00  25.000000          NaN              NaN
# 5             8.0           100.00  23.250000          NaN              NaN
# 6             1.0           100.00  28.000000          1.0           100.00
# 7             1.0           100.00  28.000000          1.0           100.00
# 8             1.0           100.00  29.000000          1.0           100.00
# 9             1.0           100.00  29.000000          1.0           100.00
# 10            2.0           100.00  20.000000          NaN              NaN
# 11            NaN              NaN  22.000000          NaN              NaN
# 12            1.0           100.00  18.000000          1.0           100.00
# 13            NaN              NaN  24.111111          2.0            11.11
# 14           11.0           100.00  23.181818          NaN              NaN
# 15            6.0           100.00  23.500000          NaN              NaN
# 16            9.0           100.00  23.222222          NaN              NaN
# 17            6.0           100.00  23.333333          NaN              NaN
# 18            1.0           100.00  26.000000          1.0           100.00
# 19            6.0           100.00  23.500000          NaN              NaN
# 20           12.0           100.00  25.000000          NaN              NaN
# 21            1.0           100.00  27.000000          1.0           100.00
# 22            1.0            50.00  27.500000          2.0           100.00
# 23            6.0           100.00  34.333333          NaN              NaN
# 24            NaN              NaN  22.000000          1.0           100.00
# 25            2.0           100.00  20.000000          NaN              NaN
# 26            2.0           100.00  33.000000          NaN              NaN
# 27            1.0           100.00  36.000000          1.0           100.00
# 28           77.0            65.81  24.504274         10.0             8.55
# 29            1.0           100.00  42.000000          1.0           100.00
# ...           ...              ...        ...          ...              ...
# 454658        NaN              NaN  21.000000          NaN              NaN
# 454659        NaN              NaN  21.000000          NaN              NaN
# 454660        NaN              NaN  21.000000          1.0           100.00
# 454661        NaN              NaN  21.000000          NaN              NaN
# 454662        NaN              NaN  21.000000          NaN              NaN
# 454663        NaN              NaN  21.000000          NaN              NaN
# 454664        NaN              NaN  21.000000          NaN              NaN
# 454665        NaN              NaN  21.000000          NaN              NaN
# 454666        NaN              NaN  21.000000          1.0           100.00
# 454667        NaN              NaN  21.000000          1.0           100.00
# 454668        NaN              NaN  21.000000          NaN              NaN
# 454669        NaN              NaN  21.000000          NaN              NaN
# 454670        NaN              NaN  21.000000          NaN              NaN
# 454671        NaN              NaN  21.000000          NaN              NaN
# 454672        NaN              NaN  21.000000          NaN              NaN
# 454673        NaN              NaN  21.000000          1.0           100.00
# 454674        NaN              NaN  21.000000          NaN              NaN
# 454675        NaN              NaN  21.000000          1.0           100.00
# 454676        NaN              NaN  21.000000          1.0           100.00
# 454677        4.0           100.00  23.000000          NaN              NaN
# 454678        NaN              NaN  21.000000          1.0           100.00
# 454679        NaN              NaN  21.000000          1.0           100.00
# 454680        NaN              NaN  21.000000          NaN              NaN
# 454681        NaN              NaN  21.000000          NaN              NaN
# 454682        NaN              NaN  21.000000          1.0           100.00
# 454683        NaN              NaN  20.000000          1.0           100.00
# 454684        NaN              NaN  20.000000          1.0           100.00
# 454685        NaN              NaN  21.000000          NaN              NaN
# 454686        NaN              NaN  21.000000          1.0           100.00
# 454687        1.0            20.00  25.400000          3.0            60.00
#
# [454688 rows x 7 columns]

# %% [markdown]
# Now, we can see that our final data set has an additional of percentage came from the user who played the song exactly once. The `NaN` value in the data set means that there is no user who only played the song exactly once, all the user like the song and played it more than once.

# %% [markdown]
# ## Percentage of plays that came from a user who played the song at least five times

# %% [markdown]
# In this section, we are going to compute the percentage of song came from the user who played the song at least five times. First, we can used the dataset from the previous section and select the user who played the song at least 5 times.

# %%
played5 = userplayed[userplayed['By User'] >= 5 ]
played5
# Out:
#                                                 Track Name      User ID  \
# 1                                                ~Kuuhaku~  user_000033
# 3                                             ! (Foreword)  user_000026
# 5                                             ! (Foreword)  user_000182
# 6                                             ! (Foreword)  user_000206
# 9                                              ! (Forward)  user_000306
# 11       ! (Performed By Ghostface Killah And Rhythm Ro...  user_000351
# 22                                                  !@*$%#  user_000251
# 24                                      !Fire In The Hole!  user_000349
# 28                                              !Kamikaze!  user_000349
# 34                                                       #  user_000306
# 44                                                      #1  user_000010
# 45                                                      #1  user_000012
# 63                                                      #1  user_000309
# 67                                              #1 Bad Boy  user_000054
# 69                                                #1 Crush  user_000074
# 70                                                #1 Crush  user_000095
# 72                                                #1 Crush  user_000131
# 77                                                #1 Crush  user_000239
# 85                                         #1 Crush (Live)  user_000131
# 87                                                  #1 Fan  user_000278
# 96                                            #1 Must Have  user_000089
# 99                                            #1 Must Have  user_000348
# 102                                      #1 Song In Heaven  user_000132
# 103                                      #1 Song In Heaven  user_000134
# 110                                                #1 Zero  user_000348
# 163                                                     #2  user_000040
# 215                                                    #34  user_000273
# 229                                                     #4  user_000182
# 251                                        #51 Dick Butkus  user_000021
# 252                                        #51 Dick Butkus  user_000199
# ...                                                    ...          ...
# 1154139                                              Ｓｔｏｒｍ  user_000141
# 1154142                                            Ｔａｃｔｉｃｓ  user_000141
# 1154143                                              Ｔｅａｒｓ  user_000141
# 1154144                            Ｔｈｉｓ　Ｎｉｇｈｔ（Ｅｑｕｉｐ　Ｒｅｍｉｘ）  user_000141
# 1154145                             Ｔｈｉｓ　Ｎｉｇｈｔ（Ｌｅｓｓ　Ｖｏｃａｌ）  user_000141
# 1154146      Ｔｈｉｓ　Ｎｉｇｈｔ（Ｔｂｓ・Ｍｂｓ系土曜アニメ「地球へ…」７月クールエンディングテーマ）  user_000141
# 1154147                                   Ｔｏ　Ｔｈｅ　Ｗｏｒｌｄ（Ｓｅ）  user_000141
# 1154149                            Ｔｏｎｉｇｈｔ，Ｔｏｎｉｇｈｔ，Ｔｏｎｉｇｈｔ  user_000141
# 1154150                                   Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ  user_000141
# 1154151  Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ（日本テレビ系全国ネット「Ｔｏｙｏｔａ　プレゼンツ　Ｆｉｆａ...  user_000141
# 1154152                       Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ（Ｌｅｓｓ　Ｖｏｃａｌ）  user_000141
# 1154153  Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ（Ｒｙｕｋｙｕｄｉｓｋｏ　Ｔｒｏｐｉｃａｌ　Ｂｅａｃｈ　Ｒｅ...  user_000141
# 1154154                                          Ｔｏｕｃｈメドレー  user_000141
# 1154157                                                Ｔｗｏ  user_000141
# 1154158                                         Ｔｗｏ　Ａｓ　Ｏｎｅ  user_000141
# 1154159                         Ｔｗｏ　Ａｓ　Ｏｎｅ（Ｄｅｐａｐｅｐｅ　Ｒｅｍｉｘ）  user_000141
# 1154160                      Ｔｗｏ　Ａｓ　Ｏｎｅ（Ｔｏｙｏｔａ「Ｗｉｓｈ」Ｃｍソング）  user_000141
# 1154163                                  Ｕｎｋｎｏｗｎ　Ｏｒｃｈｅｓｔｒａ  user_000141
# 1154164                      Ｕｎｋｎｏｗｎ　Ｏｒｃｈｅｓｔｒａ（Ａｌｂｕｍ　Ｖｅｒ．）  user_000141
# 1154165                                                 Ｕｓ  user_000141
# 1154168                                      Ｗａｓｕｅｎａｉ　Ｋａｒａ  user_000141
# 1154172  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...  user_000141
# 1154175                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ  user_000141
# 1154176                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）  user_000141
# 1154179                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ  user_000141
# 1154181               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）  user_000141
# 1154182                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ  user_000141
# 1154183                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ  user_000141
# 1154191                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～  user_000141
# 1154196                                          ､ﾏ､隕Vｪｺﾄﾁ  user_000141
#
#          By User
# 1             50
# 3              8
# 5              6
# 6             17
# 9              6
# 11             5
# 22            14
# 24             9
# 28             7
# 34            12
# 44            23
# 45            29
# 63            35
# 67            47
# 69            22
# 70             8
# 72            12
# 77             8
# 85             7
# 87             5
# 96             7
# 99             9
# 102            7
# 103           21
# 110           13
# 163            5
# 215           11
# 229            5
# 251            5
# 252           28
# ...          ...
# 1154139       43
# 1154142        9
# 1154143        6
# 1154144        9
# 1154145        7
# 1154146       10
# 1154147       21
# 1154149       28
# 1154150       10
# 1154151       19
# 1154152        5
# 1154153        5
# 1154154       11
# 1154157        5
# 1154158        7
# 1154159        9
# 1154160       10
# 1154163       20
# 1154164       74
# 1154165       11
# 1154168        6
# 1154172       27
# 1154175       28
# 1154176       25
# 1154179       12
# 1154181        7
# 1154182        9
# 1154183        9
# 1154191       17
# 1154196       10
#
# [267702 rows x 3 columns]

# %% [markdown]
# Next, we can compute how many user has played the song exactly once for each song.

# %%
sumplayed5 = played5.groupby(['Track Name']).size().reset_index(name='Played Five')
sumplayed5
# Out:
#                                                Track Name  Played Five
# 0                                               ~Kuuhaku~            1
# 1                                            ! (Foreword)            3
# 2                                             ! (Forward)            1
# 3       ! (Performed By Ghostface Killah And Rhythm Ro...            1
# 4                                                  !@*$%#            1
# 5                                      !Fire In The Hole!            1
# 6                                              !Kamikaze!            1
# 7                                                       #            1
# 8                                                      #1            3
# 9                                              #1 Bad Boy            1
# 10                                               #1 Crush            4
# 11                                        #1 Crush (Live)            1
# 12                                                 #1 Fan            1
# 13                                           #1 Must Have            2
# 14                                      #1 Song In Heaven            2
# 15                                                #1 Zero            1
# 16                                                     #2            1
# 17                                                    #34            1
# 18                                                     #4            1
# 19                                        #51 Dick Butkus            2
# 20                                               #9 Dream            5
# 21                                                   $$$$            2
# 22                                            $10 Miracle            1
# 23                                             $100 Cover            1
# 24                                          $1000 Wedding            1
# 25                                             $2,400,000            1
# 26                                                    $20            2
# 27                                                  $4.95            1
# 28                                                 & Down            2
# 29                                         &#181; &#8734;            1
# ...                                                   ...          ...
# 138172                                              Ｓｔｏｒｍ            1
# 138173                                            Ｔａｃｔｉｃｓ            1
# 138174                                              Ｔｅａｒｓ            1
# 138175                            Ｔｈｉｓ　Ｎｉｇｈｔ（Ｅｑｕｉｐ　Ｒｅｍｉｘ）            1
# 138176                             Ｔｈｉｓ　Ｎｉｇｈｔ（Ｌｅｓｓ　Ｖｏｃａｌ）            1
# 138177      Ｔｈｉｓ　Ｎｉｇｈｔ（Ｔｂｓ・Ｍｂｓ系土曜アニメ「地球へ…」７月クールエンディングテーマ）            1
# 138178                                   Ｔｏ　Ｔｈｅ　Ｗｏｒｌｄ（Ｓｅ）            1
# 138179                            Ｔｏｎｉｇｈｔ，Ｔｏｎｉｇｈｔ，Ｔｏｎｉｇｈｔ            1
# 138180                                   Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ            1
# 138181  Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ（日本テレビ系全国ネット「Ｔｏｙｏｔａ　プレゼンツ　Ｆｉｆａ...            1
# 138182                       Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ（Ｌｅｓｓ　Ｖｏｃａｌ）            1
# 138183  Ｔｏｐ　Ｏｆ　Ｔｈｅ　Ｗｏｒｌｄ（Ｒｙｕｋｙｕｄｉｓｋｏ　Ｔｒｏｐｉｃａｌ　Ｂｅａｃｈ　Ｒｅ...            1
# 138184                                          Ｔｏｕｃｈメドレー            1
# 138185                                                Ｔｗｏ            1
# 138186                                         Ｔｗｏ　Ａｓ　Ｏｎｅ            1
# 138187                         Ｔｗｏ　Ａｓ　Ｏｎｅ（Ｄｅｐａｐｅｐｅ　Ｒｅｍｉｘ）            1
# 138188                      Ｔｗｏ　Ａｓ　Ｏｎｅ（Ｔｏｙｏｔａ「Ｗｉｓｈ」Ｃｍソング）            1
# 138189                                  Ｕｎｋｎｏｗｎ　Ｏｒｃｈｅｓｔｒａ            1
# 138190                      Ｕｎｋｎｏｗｎ　Ｏｒｃｈｅｓｔｒａ（Ａｌｂｕｍ　Ｖｅｒ．）            1
# 138191                                                 Ｕｓ            1
# 138192                                      Ｗａｓｕｅｎａｉ　Ｋａｒａ            1
# 138193  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...            1
# 138194                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ            1
# 138195                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）            1
# 138196                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ            1
# 138197               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）            1
# 138198                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ            1
# 138199                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ            1
# 138200                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～            1
# 138201                                          ､ﾏ､隕Vｪｺﾄﾁ            1
#
# [138202 rows x 2 columns]

# %% [markdown]
# And then, merge the value into our final data set.

# %%
summarydf = summarydf.join(sumplayed5.set_index(['Track Name']), on=summarydf['Track Name'])
summarydf
# Out:
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage    AVG Age  Played Once  Once Percentage  \
# 0             NaN              NaN  20.000000          1.0           100.00
# 1             NaN              NaN  20.000000          NaN              NaN
# 2             2.0           100.00  30.000000          NaN              NaN
# 3            13.0            34.21  24.526316          1.0             2.63
# 4             6.0           100.00  25.000000          NaN              NaN
# 5             8.0           100.00  23.250000          NaN              NaN
# 6             1.0           100.00  28.000000          1.0           100.00
# 7             1.0           100.00  28.000000          1.0           100.00
# 8             1.0           100.00  29.000000          1.0           100.00
# 9             1.0           100.00  29.000000          1.0           100.00
# 10            2.0           100.00  20.000000          NaN              NaN
# 11            NaN              NaN  22.000000          NaN              NaN
# 12            1.0           100.00  18.000000          1.0           100.00
# 13            NaN              NaN  24.111111          2.0            11.11
# 14           11.0           100.00  23.181818          NaN              NaN
# 15            6.0           100.00  23.500000          NaN              NaN
# 16            9.0           100.00  23.222222          NaN              NaN
# 17            6.0           100.00  23.333333          NaN              NaN
# 18            1.0           100.00  26.000000          1.0           100.00
# 19            6.0           100.00  23.500000          NaN              NaN
# 20           12.0           100.00  25.000000          NaN              NaN
# 21            1.0           100.00  27.000000          1.0           100.00
# 22            1.0            50.00  27.500000          2.0           100.00
# 23            6.0           100.00  34.333333          NaN              NaN
# 24            NaN              NaN  22.000000          1.0           100.00
# 25            2.0           100.00  20.000000          NaN              NaN
# 26            2.0           100.00  33.000000          NaN              NaN
# 27            1.0           100.00  36.000000          1.0           100.00
# 28           77.0            65.81  24.504274         10.0             8.55
# 29            1.0           100.00  42.000000          1.0           100.00
# ...           ...              ...        ...          ...              ...
# 454658        NaN              NaN  21.000000          NaN              NaN
# 454659        NaN              NaN  21.000000          NaN              NaN
# 454660        NaN              NaN  21.000000          1.0           100.00
# 454661        NaN              NaN  21.000000          NaN              NaN
# 454662        NaN              NaN  21.000000          NaN              NaN
# 454663        NaN              NaN  21.000000          NaN              NaN
# 454664        NaN              NaN  21.000000          NaN              NaN
# 454665        NaN              NaN  21.000000          NaN              NaN
# 454666        NaN              NaN  21.000000          1.0           100.00
# 454667        NaN              NaN  21.000000          1.0           100.00
# 454668        NaN              NaN  21.000000          NaN              NaN
# 454669        NaN              NaN  21.000000          NaN              NaN
# 454670        NaN              NaN  21.000000          NaN              NaN
# 454671        NaN              NaN  21.000000          NaN              NaN
# 454672        NaN              NaN  21.000000          NaN              NaN
# 454673        NaN              NaN  21.000000          1.0           100.00
# 454674        NaN              NaN  21.000000          NaN              NaN
# 454675        NaN              NaN  21.000000          1.0           100.00
# 454676        NaN              NaN  21.000000          1.0           100.00
# 454677        4.0           100.00  23.000000          NaN              NaN
# 454678        NaN              NaN  21.000000          1.0           100.00
# 454679        NaN              NaN  21.000000          1.0           100.00
# 454680        NaN              NaN  21.000000          NaN              NaN
# 454681        NaN              NaN  21.000000          NaN              NaN
# 454682        NaN              NaN  21.000000          1.0           100.00
# 454683        NaN              NaN  20.000000          1.0           100.00
# 454684        NaN              NaN  20.000000          1.0           100.00
# 454685        NaN              NaN  21.000000          NaN              NaN
# 454686        NaN              NaN  21.000000          1.0           100.00
# 454687        1.0            20.00  25.400000          3.0            60.00
#
#         Played Five
# 0               NaN
# 1               1.0
# 2               NaN
# 3               3.0
# 4               1.0
# 5               1.0
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              1.0
# 14              1.0
# 15              NaN
# 16              1.0
# 17              NaN
# 18              NaN
# 19              NaN
# 20              1.0
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              3.0
# 29              NaN
# ...             ...
# 454658          NaN
# 454659          NaN
# 454660          NaN
# 454661          1.0
# 454662          NaN
# 454663          NaN
# 454664          1.0
# 454665          1.0
# 454666          NaN
# 454667          NaN
# 454668          1.0
# 454669          NaN
# 454670          1.0
# 454671          1.0
# 454672          1.0
# 454673          NaN
# 454674          NaN
# 454675          NaN
# 454676          NaN
# 454677          NaN
# 454678          NaN
# 454679          NaN
# 454680          1.0
# 454681          NaN
# 454682          NaN
# 454683          NaN
# 454684          NaN
# 454685          1.0
# 454686          NaN
# 454687          NaN
#
# [454688 rows x 8 columns]

# %%
summarydf['Fifth Percentage'] = (summarydf['Played Five'] / summarydf['Number of Played']) * 100
summarydf = summarydf.infer_objects() #convert datatypes
print summarydf.dtypes

summarydf['Fifth Percentage'] = summarydf['Fifth Percentage'].round(2)
summarydf['AVG Age'] = summarydf['AVG Age'].round(2)
summarydf
# Out:
# Track Name           object
# Number of Played      int64
# By Gender           float64
# Male Percentage     float64
# AVG Age             float64
# Played Once         float64
# Once Percentage     float64
# Played Five         float64
# Fifth Percentage    float64
# dtype: object
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage  AVG Age  Played Once  Once Percentage  \
# 0             NaN              NaN    20.00          1.0           100.00
# 1             NaN              NaN    20.00          NaN              NaN
# 2             2.0           100.00    30.00          NaN              NaN
# 3            13.0            34.21    24.53          1.0             2.63
# 4             6.0           100.00    25.00          NaN              NaN
# 5             8.0           100.00    23.25          NaN              NaN
# 6             1.0           100.00    28.00          1.0           100.00
# 7             1.0           100.00    28.00          1.0           100.00
# 8             1.0           100.00    29.00          1.0           100.00
# 9             1.0           100.00    29.00          1.0           100.00
# 10            2.0           100.00    20.00          NaN              NaN
# 11            NaN              NaN    22.00          NaN              NaN
# 12            1.0           100.00    18.00          1.0           100.00
# 13            NaN              NaN    24.11          2.0            11.11
# 14           11.0           100.00    23.18          NaN              NaN
# 15            6.0           100.00    23.50          NaN              NaN
# 16            9.0           100.00    23.22          NaN              NaN
# 17            6.0           100.00    23.33          NaN              NaN
# 18            1.0           100.00    26.00          1.0           100.00
# 19            6.0           100.00    23.50          NaN              NaN
# 20           12.0           100.00    25.00          NaN              NaN
# 21            1.0           100.00    27.00          1.0           100.00
# 22            1.0            50.00    27.50          2.0           100.00
# 23            6.0           100.00    34.33          NaN              NaN
# 24            NaN              NaN    22.00          1.0           100.00
# 25            2.0           100.00    20.00          NaN              NaN
# 26            2.0           100.00    33.00          NaN              NaN
# 27            1.0           100.00    36.00          1.0           100.00
# 28           77.0            65.81    24.50         10.0             8.55
# 29            1.0           100.00    42.00          1.0           100.00
# ...           ...              ...      ...          ...              ...
# 454658        NaN              NaN    21.00          NaN              NaN
# 454659        NaN              NaN    21.00          NaN              NaN
# 454660        NaN              NaN    21.00          1.0           100.00
# 454661        NaN              NaN    21.00          NaN              NaN
# 454662        NaN              NaN    21.00          NaN              NaN
# 454663        NaN              NaN    21.00          NaN              NaN
# 454664        NaN              NaN    21.00          NaN              NaN
# 454665        NaN              NaN    21.00          NaN              NaN
# 454666        NaN              NaN    21.00          1.0           100.00
# 454667        NaN              NaN    21.00          1.0           100.00
# 454668        NaN              NaN    21.00          NaN              NaN
# 454669        NaN              NaN    21.00          NaN              NaN
# 454670        NaN              NaN    21.00          NaN              NaN
# 454671        NaN              NaN    21.00          NaN              NaN
# 454672        NaN              NaN    21.00          NaN              NaN
# 454673        NaN              NaN    21.00          1.0           100.00
# 454674        NaN              NaN    21.00          NaN              NaN
# 454675        NaN              NaN    21.00          1.0           100.00
# 454676        NaN              NaN    21.00          1.0           100.00
# 454677        4.0           100.00    23.00          NaN              NaN
# 454678        NaN              NaN    21.00          1.0           100.00
# 454679        NaN              NaN    21.00          1.0           100.00
# 454680        NaN              NaN    21.00          NaN              NaN
# 454681        NaN              NaN    21.00          NaN              NaN
# 454682        NaN              NaN    21.00          1.0           100.00
# 454683        NaN              NaN    20.00          1.0           100.00
# 454684        NaN              NaN    20.00          1.0           100.00
# 454685        NaN              NaN    21.00          NaN              NaN
# 454686        NaN              NaN    21.00          1.0           100.00
# 454687        1.0            20.00    25.40          3.0            60.00
#
#         Played Five  Fifth Percentage
# 0               NaN               NaN
# 1               1.0              2.00
# 2               NaN               NaN
# 3               3.0              7.89
# 4               1.0             16.67
# 5               1.0             12.50
# 6               NaN               NaN
# 7               NaN               NaN
# 8               NaN               NaN
# 9               NaN               NaN
# 10              NaN               NaN
# 11              NaN               NaN
# 12              NaN               NaN
# 13              1.0              5.56
# 14              1.0              9.09
# 15              NaN               NaN
# 16              1.0             11.11
# 17              NaN               NaN
# 18              NaN               NaN
# 19              NaN               NaN
# 20              1.0              8.33
# 21              NaN               NaN
# 22              NaN               NaN
# 23              NaN               NaN
# 24              NaN               NaN
# 25              NaN               NaN
# 26              NaN               NaN
# 27              NaN               NaN
# 28              3.0              2.56
# 29              NaN               NaN
# ...             ...               ...
# 454658          NaN               NaN
# 454659          NaN               NaN
# 454660          NaN               NaN
# 454661          1.0              3.70
# 454662          NaN               NaN
# 454663          NaN               NaN
# 454664          1.0              3.57
# 454665          1.0              4.00
# 454666          NaN               NaN
# 454667          NaN               NaN
# 454668          1.0              8.33
# 454669          NaN               NaN
# 454670          1.0             14.29
# 454671          1.0             11.11
# 454672          1.0             11.11
# 454673          NaN               NaN
# 454674          NaN               NaN
# 454675          NaN               NaN
# 454676          NaN               NaN
# 454677          NaN               NaN
# 454678          NaN               NaN
# 454679          NaN               NaN
# 454680          1.0              5.88
# 454681          NaN               NaN
# 454682          NaN               NaN
# 454683          NaN               NaN
# 454684          NaN               NaN
# 454685          1.0             10.00
# 454686          NaN               NaN
# 454687          NaN               NaN
#
# [454688 rows x 9 columns]

# %% [markdown]
# Now, we can see that our final data set has an additional of percentage came from the user who played the song at least 5 times. The `NaN` value in the data set means that there is no user who played the song more than 4 times.

# %% [markdown]
# # Dealing with a song who only have female listener

# %% [markdown]
# If there any missing values, decide how you will deal with them, and summarize your approach.
#
# 2. In this same pre-processing notebook, explore the data by generating some descriptive statistics.  After each code block, you should have summary statements, or code blocks should print out summary statements that are useful to a reader.
#
# 3. Complete this notebook by exporting the generated dataframe using pickle for posterity, but **don't commit your pickled file to the repository**.  Sometimes, it is more convenient to process the data locally rather than transmitting large processed data files.

# %% [markdown]
# As we already said before, in some variables there will be a null values. For example in the percentage of male listener, the female listener will appear as null. In the percentage of song played exactly once, the listener who listened to the song more than once will apppear as null values. Also, in the percentage of song has been played at least 5 times, the listener who played the song less than 5 will appear null. Therefore, we can set the null value as `0` to mitigate having empty values. The following code will defined the null values as `0`.

# %%
# set missing values as 0
resetsummary = summarydf.fillna(0)
resetsummary
# Out:
#                                                Track Name  Number of Played  \
# 0       \nuser_000125\t2007-11-23T04:25:49Z\t03ad1736-...                 1
# 1                                               ~Kuuhaku~                50
# 2                                                       !                 2
# 3                                            ! (Foreword)                38
# 4                                             ! (Forward)                 6
# 5       ! (Performed By Ghostface Killah And Rhythm Ro...                 8
# 6                          ! (The Song Formerly Known As)                 1
# 7                                                     ! +                 1
# 8                                      ! / Sn10.1.Ai 0711                 1
# 9                                         ! / Sn2.Ai 0853                 1
# 10                               ! Que Vida! (Stereo Mix)                 2
# 11            !!! - Me And Guliani Down By The Schoolyard                 2
# 12                            !!!Yeah!!!(Reggeaton Remix)                 1
# 13                                                 !@*$%#                18
# 14                                     !Fire In The Hole!                11
# 15                                         !Get Up, Punk!                 6
# 16                                             !Kamikaze!                 9
# 17                                  !Pimps Up, Aces High!                 6
# 18                            !Resistancia! (Bonus Track)                 1
# 19                                    !Vaqueros Y Indios!                 6
# 20                                                      #                12
# 21         # 173 - The Stills, Novillero, Fred Eaglesmith                 1
# 22                  # 174 - The Organ, Sloan, Jill Barber                 2
# 23                                                  # 807                 6
# 24                                           # Pending 24                 1
# 25                                                   #...                 2
# 26                                       #04 (Go On Home)                 2
# 27      #068 - Tad Marks, Stephen Nachmanovitch, Boldw...                 1
# 28                                                     #1               117
# 29                                    #1  (Album Version)                 1
# ...                                                   ...               ...
# 454658  Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（映画「スパイダーマン２」日本版テーマソング，日本語吹き替え版エンデ...                 4
# 454659                Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ａｌｂｕｍ　Ｖｅｒｓｉｏｎ）                 2
# 454660                      Ｗｅｂ　Ｏｆ　Ｎｉｇｈｔ（Ｅｎｇｌｉｓｈ　Ｖｅｒｓｉｏｎ）                 1
# 454661  Ｗｈａｔ’Ｓ　Ｕｐ，Ｐｅｏｐｌｅ！？（日本テレビ系アニメ「Ｄｅａｔｈ　Ｎｏｔｅ」オープニング...                27
# 454662                                          Ｗｈａｔ　Ｆｏｒ…                 2
# 454663                                       Ｗｈｉｔｅ　Ｂｒｅａｔｈ                 4
# 454664                                     Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ                28
# 454665                   Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ａｒａｓ　Ｄｅ　Ｐａｌａｂｒａｓ）                25
# 454666  Ｗｉｎｇｓ　Ｏｆ　Ｗｏｒｄｓ（Ｍｂｓ・Ｔｂｓ系列「機動戦士ガンダムＳｅｅｄ　Ｄｅｓｔｉｎｙ」...                 1
# 454667                                           Ｗｉｔｈ　Ｙｏｕ                 1
# 454668                                    Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ                12
# 454669                   Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（ルーニー・チューン・リミックス）                 4
# 454670               Ｙｏｕ　Ｇｏ　Ｙｏｕｒ　Ｗａｙ（Ｏｒｉｇｉｎａｌ　Ａｌｂｕｍ　Ｖｅｒ．）                 7
# 454671                                         Ｙｏｕ　Ｇｏｔ　Ｍｅ                 9
# 454672                               Ｙｏｕｒ　Ｎａｍｅ　Ｎｅｖｅｒ　Ｇｏｎｅ                 9
# 454673                                         Ｙｏｕｒ　Ｗｏｒｌｄ                 1
# 454674                                          Ｙｕｒａ　Ｙｕｒａ                 4
# 454675                                      Ｚｅｒｏ　Ｓｙｍｐａｔｈｙ                 1
# 454676                     Ｚｉｐｓ（「機動戦士ガンダムＳｅｅｄ　Ｍｓｖ」テーマソング）                 1
# 454677                                     ～De Merveilles                 4
# 454678                                          ～Sprout!～                 1
# 454679                                    ～Toxic Gorilla～                 1
# 454680                                  ～流れ・空虚・Ｔｈｉｓ　Ｗｏｒｄ～                17
# 454681                              ～Ｓｐｒｏｕｔ！～（インストゥルメンタル）                 2
# 454682                        ～Ｔｏｘｉｃ　Ｇｏｒｉｌｌａ～（インストゥルメンタル）                 1
# 454683                        ｢H×M×-Crash-Trap@｣ －A Type－                 1
# 454684                        ｢H×M×-Crash-Trap@｣ －B Type－                 1
# 454685                                          ､ﾏ､隕Vｪｺﾄﾁ                10
# 454686                                                ｺﾏ覈                 1
# 454687                                     �   �H H�,   �                 5
#
#         By Gender  Male Percentage  AVG Age  Played Once  Once Percentage  \
# 0             0.0             0.00    20.00          1.0           100.00
# 1             0.0             0.00    20.00          0.0             0.00
# 2             2.0           100.00    30.00          0.0             0.00
# 3            13.0            34.21    24.53          1.0             2.63
# 4             6.0           100.00    25.00          0.0             0.00
# 5             8.0           100.00    23.25          0.0             0.00
# 6             1.0           100.00    28.00          1.0           100.00
# 7             1.0           100.00    28.00          1.0           100.00
# 8             1.0           100.00    29.00          1.0           100.00
# 9             1.0           100.00    29.00          1.0           100.00
# 10            2.0           100.00    20.00          0.0             0.00
# 11            0.0             0.00    22.00          0.0             0.00
# 12            1.0           100.00    18.00          1.0           100.00
# 13            0.0             0.00    24.11          2.0            11.11
# 14           11.0           100.00    23.18          0.0             0.00
# 15            6.0           100.00    23.50          0.0             0.00
# 16            9.0           100.00    23.22          0.0             0.00
# 17            6.0           100.00    23.33          0.0             0.00
# 18            1.0           100.00    26.00          1.0           100.00
# 19            6.0           100.00    23.50          0.0             0.00
# 20           12.0           100.00    25.00          0.0             0.00
# 21            1.0           100.00    27.00          1.0           100.00
# 22            1.0            50.00    27.50          2.0           100.00
# 23            6.0           100.00    34.33          0.0             0.00
# 24            0.0             0.00    22.00          1.0           100.00
# 25            2.0           100.00    20.00          0.0             0.00
# 26            2.0           100.00    33.00          0.0             0.00
# 27            1.0           100.00    36.00          1.0           100.00
# 28           77.0            65.81    24.50         10.0             8.55
# 29            1.0           100.00    42.00          1.0           100.00
# ...           ...              ...      ...          ...              ...
# 454658        0.0             0.00    21.00          0.0             0.00
# 454659        0.0             0.00    21.00          0.0             0.00
# 454660        0.0             0.00    21.00          1.0           100.00
# 454661        0.0             0.00    21.00          0.0             0.00
# 454662        0.0             0.00    21.00          0.0             0.00
# 454663        0.0             0.00    21.00          0.0             0.00
# 454664        0.0             0.00    21.00          0.0             0.00
# 454665        0.0             0.00    21.00          0.0             0.00
# 454666        0.0             0.00    21.00          1.0           100.00
# 454667        0.0             0.00    21.00          1.0           100.00
# 454668        0.0             0.00    21.00          0.0             0.00
# 454669        0.0             0.00    21.00          0.0             0.00
# 454670        0.0             0.00    21.00          0.0             0.00
# 454671        0.0             0.00    21.00          0.0             0.00
# 454672        0.0             0.00    21.00          0.0             0.00
# 454673        0.0             0.00    21.00          1.0           100.00
# 454674        0.0             0.00    21.00          0.0             0.00
# 454675        0.0             0.00    21.00          1.0           100.00
# 454676        0.0             0.00    21.00          1.0           100.00
# 454677        4.0           100.00    23.00          0.0             0.00
# 454678        0.0             0.00    21.00          1.0           100.00
# 454679        0.0             0.00    21.00          1.0           100.00
# 454680        0.0             0.00    21.00          0.0             0.00
# 454681        0.0             0.00    21.00          0.0             0.00
# 454682        0.0             0.00    21.00          1.0           100.00
# 454683        0.0             0.00    20.00          1.0           100.00
# 454684        0.0             0.00    20.00          1.0           100.00
# 454685        0.0             0.00    21.00          0.0             0.00
# 454686        0.0             0.00    21.00          1.0           100.00
# 454687        1.0            20.00    25.40          3.0            60.00
#
#         Played Five  Fifth Percentage
# 0               0.0              0.00
# 1               1.0              2.00
# 2               0.0              0.00
# 3               3.0              7.89
# 4               1.0             16.67
# 5               1.0             12.50
# 6               0.0              0.00
# 7               0.0              0.00
# 8               0.0              0.00
# 9               0.0              0.00
# 10              0.0              0.00
# 11              0.0              0.00
# 12              0.0              0.00
# 13              1.0              5.56
# 14              1.0              9.09
# 15              0.0              0.00
# 16              1.0             11.11
# 17              0.0              0.00
# 18              0.0              0.00
# 19              0.0              0.00
# 20              1.0              8.33
# 21              0.0              0.00
# 22              0.0              0.00
# 23              0.0              0.00
# 24              0.0              0.00
# 25              0.0              0.00
# 26              0.0              0.00
# 27              0.0              0.00
# 28              3.0              2.56
# 29              0.0              0.00
# ...             ...               ...
# 454658          0.0              0.00
# 454659          0.0              0.00
# 454660          0.0              0.00
# 454661          1.0              3.70
# 454662          0.0              0.00
# 454663          0.0              0.00
# 454664          1.0              3.57
# 454665          1.0              4.00
# 454666          0.0              0.00
# 454667          0.0              0.00
# 454668          1.0              8.33
# 454669          0.0              0.00
# 454670          1.0             14.29
# 454671          1.0             11.11
# 454672          1.0             11.11
# 454673          0.0              0.00
# 454674          0.0              0.00
# 454675          0.0              0.00
# 454676          0.0              0.00
# 454677          0.0              0.00
# 454678          0.0              0.00
# 454679          0.0              0.00
# 454680          1.0              5.88
# 454681          0.0              0.00
# 454682          0.0              0.00
# 454683          0.0              0.00
# 454684          0.0              0.00
# 454685          1.0             10.00
# 454686          0.0              0.00
# 454687          0.0              0.00
#
# [454688 rows x 9 columns]

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# In addition to the above statistics, we can do some other statistics based on the original data. For example we can know the count and number of participants.

# %%
dfdropnull[['User ID', 'Track Name', 'Artist Name']].describe()
# Out:
#             User ID Track Name Artist Name
# count       5296879    5296879     5296879
# unique          271     454688       70472
# top     user_000233      Intro   Radiohead
# freq         117488       4585       34575

# %% [markdown]
# On the above output, we can know that the total observation for user id, track name, and the artist name is 5296879 for each. It also shows that there are 271 different user, 454688 different song from 70472 artists.

# %%
dfdropnull.describe(include='all')
# Out:
#             User ID             Timestamp  \
# count       5296879               5296879
# unique          271               5157105
# top     user_000233  2009-04-07T21:52:40Z
# freq         117488                   161
# mean            NaN                   NaN
# std             NaN                   NaN
# min             NaN                   NaN
# 25%             NaN                   NaN
# 50%             NaN                   NaN
# 75%             NaN                   NaN
# max             NaN                   NaN
#
#                                    Artist ID Artist Name  \
# count                                5138209     5296879
# unique                                 51611       70472
# top     a74b1b7f-71a5-4011-9441-d0b5e4122711   Radiohead
# freq                                   34575       34575
# mean                                     NaN         NaN
# std                                      NaN         NaN
# min                                      NaN         NaN
# 25%                                      NaN         NaN
# 50%                                      NaN         NaN
# 75%                                      NaN         NaN
# max                                      NaN         NaN
#
#                                     Track ID Track Name   gender  \
# count                                4694916    5296879  5296879
# unique                                433584     454688        2
# top     153d8ca0-dc23-4548-b64f-2c49db7f30db      Intro        m
# freq                                    2367       4585  3466064
# mean                                     NaN        NaN      NaN
# std                                      NaN        NaN      NaN
# min                                      NaN        NaN      NaN
# 25%                                      NaN        NaN      NaN
# 50%                                      NaN        NaN      NaN
# 75%                                      NaN        NaN      NaN
# max                                      NaN        NaN      NaN
#
#                  age        country    registered
# count   5.296879e+06        5208066       5296879
# unique           NaN             44           230
# top              NaN  United States  Jul 20, 2005
# freq             NaN        1253710        117488
# mean    2.495218e+01            NaN           NaN
# std     6.100131e+00            NaN           NaN
# min     3.000000e+00            NaN           NaN
# 25%     2.100000e+01            NaN           NaN
# 50%     2.400000e+01            NaN           NaN
# 75%     2.800000e+01            NaN           NaN
# max     7.500000e+01            NaN           NaN

# %% [markdown]
# In regards to our precessed data, we can know the details decriptive statistics by using the following code.

# %%
resetsummary.describe(include='all')
# Out:
#                       Track Name  Number of Played      By Gender  \
# count                     454688     454688.000000  454688.000000
# unique                    454688               NaN            NaN
# top     Power Outage At The Pool               NaN            NaN
# freq                           1               NaN            NaN
# mean                         NaN         11.649481       7.622950
# std                          NaN         38.802318      26.977751
# min                          NaN          1.000000       0.000000
# 25%                          NaN          1.000000       1.000000
# 50%                          NaN          3.000000       1.000000
# 75%                          NaN          8.000000       5.000000
# max                          NaN       4585.000000    3154.000000
#
#         Male Percentage        AVG Age    Played Once  Once Percentage  \
# count     454688.000000  454688.000000  454688.000000    454688.000000
# unique              NaN            NaN            NaN              NaN
# top                 NaN            NaN            NaN              NaN
# freq                NaN            NaN            NaN              NaN
# mean          67.217073      26.445792       1.136520        43.088301
# std           42.568355       6.716780       2.026046        46.369161
# min            0.000000       3.000000       0.000000         0.000000
# 25%           14.290000      22.000000       0.000000         0.000000
# 50%          100.000000      25.000000       1.000000        15.150000
# 75%          100.000000      29.330000       1.000000       100.000000
# max          100.000000      75.000000      41.000000       100.000000
#
#           Played Five  Fifth Percentage
# count   454688.000000     454688.000000
# unique            NaN               NaN
# top               NaN               NaN
# freq              NaN               NaN
# mean         0.588760          2.827662
# std          1.810893          5.110601
# min          0.000000          0.000000
# 25%          0.000000          0.000000
# 50%          0.000000          0.000000
# 75%          1.000000          4.550000
# max        145.000000         20.000000

# %% [markdown]
# On the above output, we can see the number of observations, the mean, median, min, max, and the quantiles of the data.

# %% [markdown]
# ## Pickling the processed dataframe

# %%
pickle_out = open('data.pkl', 'wb')
pickle.dump(resetsummary, pickle_out, pickle.HIGHEST_PROTOCOL)
pickle_out.close()
